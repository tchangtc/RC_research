# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv(f'/home/workspace/AMP_mysef_2D_Cls/MyDataset/0327_img_mask_nonzero_1.csv')
patient_id = train_df.img_dir.unique()
patient_id = sorted(patient_id)

num_fold=5
rs = np.random.RandomState(1234)
rs.shuffle(patient_id)
patient_id = np.array(patient_id)
f = np.arange(len(patient_id))%num_fold
train_id = patient_id[f!=fold]
valid_id = patient_id[f==fold]

train_df = df[df.img_dir.isin(train_id)].reset_index(drop=True)
valid_df = df[df.img_dir.isin(valid_id)].reset_index(drop=True)

# %%
train_df = pd.read_csv(f'/home/workspace/AMP_mysef_2D_Cls/MyDataset/0327_img_mask_nonzero_1.csv')
patient_id = train_df.img_dir.unique()
patient_id = sorted(patient_id)
train_id = patient_id
train_df = train_df[train_df.img_dir.isin(train_id)].reset_index(drop=True)
train_df

# %%
df = pd.read_csv(f'/home/workspace/AMP_mysef_2D_Cls/MyDataset/0327_img_mask_nonzero_1.csv')
patient_id = df.img_dir.unique()
patient_id = sorted(patient_id)
fold=1
num_fold=5
rs = np.random.RandomState(1234)
rs.shuffle(patient_id)
patient_id = np.array(patient_id)
f = np.arange(len(patient_id))%num_fold
train_id = patient_id[f!=fold]
valid_id = patient_id[f==fold]

train_df = df[df.img_dir.isin(train_id)].reset_index(drop=True)
valid_df = df[df.img_dir.isin(valid_id)].reset_index(drop=True)

# %%
train_df
valid_df

# %%
import pandas as pd
train_df = pd.read_csv(f'/home/workspace/AMP_mysef_2D_Cls/MyDataset/0327_img_mask_nonzero_1.csv')
train_patient_id = train_df.img_dir.unique()
train_patient_id = sorted(train_patient_id)
train_id = train_patient_id
train_df = train_df[train_df.img_dir.isin(train_id)].reset_index(drop=True)

test_df = pd.read_csv(f'/home/workspace/AMP_mysef_2D_Cls/MyDataset/0327_test_img_mask_nonzero.csv')
test_patient_id = test_df.img_dir.unique()
test_patient_id = sorted(test_patient_id)
test_id = test_patient_id
test_df = test_df[test_df.img_dir.isin(test_id)].reset_index(drop=True)

# %%
train_df
test_df
# Out:
#      Unnamed: 0  img_dir         img_name  \
# 0             0  crc_266  crc_266_004.png
# 1             1  crc_266  crc_266_005.png
# 2             2  crc_266  crc_266_006.png
# 3             3  crc_266  crc_266_007.png
# 4             4  crc_266  crc_266_008.png
# ..          ...      ...              ...
# 510         510  crc_319  crc_319_015.png
# 511         511  crc_319  crc_319_016.png
# 512         512  crc_319  crc_319_017.png
# 513         513  crc_319  crc_319_018.png
# 514         514  crc_319  crc_319_019.png
#
#                                               img_path  \
# 0    /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 1    /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 2    /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 3    /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 4    /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# ..                                                 ...
# 510  /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 511  /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 512  /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 513  /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
# 514  /home/workspace/AMP_mysef_2D_Cls/data/png_img_...
#
#                                              mask_path  T_Stage
# 0    /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        1
# 1    /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        1
# 2    /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        1
# 3    /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        1
# 4    /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        1
# ..                                                 ...      ...
# 510  /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        0
# 511  /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        0
# 512  /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        0
# 513  /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        0
# 514  /home/workspace/AMP_mysef_2D_Cls/data/png_mask...        0
#
# [515 rows x 6 columns]

# %%
# test_df = test_df.drop(['Unnamed: 0.1'], axis=1)
# test_df

# %%
# test_df.to_csv('./0327_test_img_mask_nonzero.csv')
