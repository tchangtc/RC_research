# %%
import pandas as pd

# %%
csv = pd.read_csv('./tstage.csv')
csv
# Out:
#       id      mri  T_stage
# 0      1  crc_001        0
# 1      2  crc_002        0
# 2      3  crc_003        0
# 3      4  crc_004        0
# 4      5  crc_005        0
# ..   ...      ...      ...
# 260  261  crc_261        0
# 261  262  crc_262        0
# 262  263  crc_263        0
# 263  264  crc_264        0
# 264  265  crc_265        0
#
# [265 rows x 3 columns]

# %%
dict = {}

for i in range(len(csv)):
    # print(i)
    dict[csv['mri'][i]] = int(csv['T_stage'][i])

# %%
dict
# Out:
# {'crc_001': 0,
#  'crc_002': 0,
#  'crc_003': 0,
#  'crc_004': 0,
#  'crc_005': 0,
#  'crc_006': 1,
#  'crc_007': 0,
#  'crc_008': 1,
#  'crc_009': 0,
#  'crc_010': 1,
#  'crc_011': 1,
#  'crc_012': 1,
#  'crc_013': 0,
#  'crc_014': 1,
#  'crc_015': 1,
#  'crc_016': 1,
#  'crc_017': 0,
#  'crc_018': 0,
#  'crc_019': 0,
#  'crc_020': 1,
#  'crc_021': 1,
#  'crc_022': 0,
#  'crc_023': 0,
#  'crc_024': 0,
#  'crc_025': 0,
#  'crc_026': 0,
#  'crc_027': 0,
#  'crc_028': 1,
#  'crc_029': 1,
#  'crc_030': 0,
#  'crc_031': 0,
#  'crc_032': 1,
#  'crc_033': 1,
#  'crc_034': 0,
#  'crc_035': 0,
#  'crc_036': 1,
#  'crc_037': 1,
#  'crc_038': 1,
#  'crc_039': 1,
#  'crc_040': 0,
#  'crc_041': 0,
#  'crc_042': 0,
#  'crc_043': 0,
#  'crc_044': 0,
#  'crc_045': 1,
#  'crc_046': 0,
#  'crc_047': 0,
#  'crc_048': 0,
#  'crc_049': 0,
#  'crc_050': 1,
#  'crc_051': 0,
#  'crc_052': 0,
#  'crc_053': 0,
#  'crc_054': 0,
#  'crc_055': 0,
#  'crc_056': 1,
#  'crc_057': 1,
#  'crc_058': 1,
# ...

# %%
import json
a = json.dumps(dict)
f2 = open('name_to_T.json', 'w')
f2.write(a)
f2.close()

# %%
csv = pd.read_csv(f'/home/workspace/AMP_mysef_2D_Cls/MyDataset/test_cls_stage.csv')
csv
# Out:
#      id      mri  T_stage
# 0   266  crc_266        1
# 1   267  crc_267        0
# 2   268  crc_268        0
# 3   269  crc_269        1
# 4   270  crc_270        1
# 5   271  crc_271        0
# 6   272  crc_272        1
# 7   273  crc_273        1
# 8   274  crc_274        1
# 9   275  crc_275        0
# 10  276  crc_276        1
# 11  278  crc_278        0
# 12  279  crc_279        1
# 13  280  crc_280        0
# 14  282  crc_282        0
# 15  283  crc_283        1
# 16  284  crc_284        0
# 17  285  crc_285        1
# 18  286  crc_286        1
# 19  287  crc_287        1
# 20  288  crc_288        1
# 21  289  crc_289        1
# 22  290  crc_290        0
# 23  291  crc_291        1
# 24  292  crc_292        0
# 25  293  crc_293        1
# 26  294  crc_294        0
# 27  295  crc_295        0
# 28  296  crc_296        1
# 29  297  crc_297        0
# 30  298  crc_298        0
# 31  299  crc_299        0
# 32  300  crc_300        1
# 33  301  crc_301        0
# ...

# %%
dict = {}

for i in range(len(csv)):
    # print(i)
    dict[csv['mri'][i]] = int(csv['T_stage'][i])

# %%
dict
# Out:
# {'crc_266': 1,
#  'crc_267': 0,
#  'crc_268': 0,
#  'crc_269': 1,
#  'crc_270': 1,
#  'crc_271': 0,
#  'crc_272': 1,
#  'crc_273': 1,
#  'crc_274': 1,
#  'crc_275': 0,
#  'crc_276': 1,
#  'crc_278': 0,
#  'crc_279': 1,
#  'crc_280': 0,
#  'crc_282': 0,
#  'crc_283': 1,
#  'crc_284': 0,
#  'crc_285': 1,
#  'crc_286': 1,
#  'crc_287': 1,
#  'crc_288': 1,
#  'crc_289': 1,
#  'crc_290': 0,
#  'crc_291': 1,
#  'crc_292': 0,
#  'crc_293': 1,
#  'crc_294': 0,
#  'crc_295': 0,
#  'crc_296': 1,
#  'crc_297': 0,
#  'crc_298': 0,
#  'crc_299': 0,
#  'crc_300': 1,
#  'crc_301': 0,
#  'crc_302': 0,
#  'crc_303': 1,
#  'crc_304': 0,
#  'crc_305': 1,
#  'crc_306': 1,
#  'crc_307': 1,
#  'crc_308': 0,
#  'crc_309': 0,
#  'crc_310': 1,
#  'crc_311': 1,
#  'crc_312': 0,
#  'crc_313': 0,
#  'crc_314': 0,
#  'crc_315': 1,
#  'crc_316': 1,
#  'crc_317': 1,
#  'crc_318': 1,
#  'crc_319': 0}

# %%
import json
a = json.dumps(dict)
f2 = open('test_name_to_T.json', 'w')
f2.write(a)
f2.close()
